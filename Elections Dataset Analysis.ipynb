# %% [markdown]
# # EDA on General Elections Dataset
#
# Samples were collected over a period of nine days where the respondants were asked questions related to results of general elections. Survey weights are in the 'weight' column. The data analysis will be done with the help of some questions with the help of few libraries and visualization is done accordingly.

# %%
import pandas as pd                       # Importing general python libraries for doing analysis for below questions
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Question 1 - Load the dataset into a pandas dataframe. Name the variable as “survey”.**

# %%
survey= pd.read_csv(r"F:\Techstack DA Classes\Data and Recordings\Python\DSL Datasets\DSL Datasets\10. Elections Project.csv")

# %%
survey
# Out:
#       response_id collection_date urban_rural               education  \
# 0               1       5-24-2017       Rural               12th Pass
# 1               2       5-24-2017       Rural                Graduate
# 2               3       5-24-2017       Rural                Graduate
# 3               4       5-24-2017       Urban                Graduate
# 4               5       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6862         6863        6-1-2017       Rural               10th Pass
# 6863         6864        6-1-2017       Rural                Graduate
# 6864         6865        6-1-2017       Urban                Graduate
# 6865         6866        6-1-2017       Rural  Professional Education
# 6866         6867        6-1-2017       Rural               10th Pass
#
#                    income Vote_Now     Past_Vote     CM_satisfaction  \
# ...

# %% [markdown]
# **Question 2 - How many samples were collected on each day?**

# %%
survey.collection_date.value_counts()
# Out:
# collection_date
# 5-24-2017    1479
# 5-25-2017     998
# 5-28-2017     761
# 5-27-2017     665
# 5-29-2017     620
# 6-1-2017      607
# 5-26-2017     598
# 5-30-2017     582
# 5-31-2017     557
# Name: count, dtype: int64

# %% [markdown]
# **Question 3 - What proportion of the total respondents were aged less than 45?**

# %%
survey.head(2)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
#
#   Vote_Now Past_Vote     CM_satisfaction    MLA_satisfaction age gender  \
# 0      BJP       BJP  Fully Dissatisfied  Fully Dissatisfied  26   Male
# 1     RLSP     JD(U)  Somewhat Satisfied  Fully Dissatisfied  34   Male
#
#    assembly_no category    weight
# 0          211      Gen  0.346969
# 1          189       BC  0.603419

# %%
survey.age.unique()
# Out:
# array(['26', '34', '25', '36', '22', '38', '23', '42', '51', '29', '24',
#        '30', '39', '37', '19', '44', '53', '32', '21', '18', '20', '27',
#        '48', '28', '45', '74', '35', '31', '70', '40', '49', '46', '43',
#        '41', '33', '58', '24ko', '56', '50', '55', '54', '62', '60', '59',
#        '47', '61', '52', '66', '57', '67', '65', '71', '63', '64', '68',
#        '69', '99', '72', '75', '76'], dtype=object)

# %%
survey.age.dtype
# Out:
# dtype('O')

# %%
survey.age.replace({"24ko": 24}, inplace=True)

# %%
survey.age.value_counts()
# Out:
# age
# 25    598
# 24    449
# 30    440
# 28    396
# 22    392
# 26    389
# 27    360
# 20    328
# 23    317
# 21    311
# 32    263
# 35    263
# 29    239
# 40    177
# 34    173
# 19    171
# 31    159
# 33    143
# 38    135
# 36    127
# 18    125
# 42    104
# 37     90
# 45     82
# 43     72
# 39     69
# 50     60
# 41     54
# 44     54
# 48     35
# 47     34
# 46     32
# 49     27
# 52     24
# 51     23
# 55     20
# 60     15
# 53     12
# 61     12
# 54     11
# 57     10
# 56      9
# 58      9
# 64      8
# 67      7
# 62      5
# 59      5
# 65      5
# 68      4
# 63      4
# 66      4
# 70      3
# 71      2
# 74      1
# 24      1
# 69      1
# 99      1
# 72      1
# 75      1
# 76      1
# Name: count, dtype: int64

# %%
survey[survey.age < 45]
# Out:
#       response_id collection_date urban_rural               education  \
# 0               1       5-24-2017       Rural               12th Pass
# 1               2       5-24-2017       Rural                Graduate
# 2               3       5-24-2017       Rural                Graduate
# 3               4       5-24-2017       Urban                Graduate
# 4               5       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6862         6863        6-1-2017       Rural               10th Pass
# 6863         6864        6-1-2017       Rural                Graduate
# 6864         6865        6-1-2017       Urban                Graduate
# 6865         6866        6-1-2017       Rural  Professional Education
# 6866         6867        6-1-2017       Rural               10th Pass
#
#                    income Vote_Now     Past_Vote     CM_satisfaction  \
# ...

# %%
survey["age"]= survey.age.astype(int)

# %%
6399/6867 *100
# Out:
# 93.18479685452162

# %% [markdown]
# **Question 4 - Create a new column in the dataframe “age_group”. This column should contain the age group the respondent belongs to. The age groups are 18-25, 25-40, 40-55 and 55+. Show the age group distribution with the help of a pie chart.**

# %%
data= survey.copy()           # creating a copy of original dataframe 'survey'

# %%
data.head(2)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
#
#   Vote_Now Past_Vote     CM_satisfaction    MLA_satisfaction  age gender  \
# 0      BJP       BJP  Fully Dissatisfied  Fully Dissatisfied   26   Male
# 1     RLSP     JD(U)  Somewhat Satisfied  Fully Dissatisfied   34   Male
#
#    assembly_no category    weight
# 0          211      Gen  0.346969
# 1          189       BC  0.603419

# %%
data.insert(10, "age_group", data.age)            # Adding a new column

# %%
data.head(2)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
#
#   Vote_Now Past_Vote     CM_satisfaction    MLA_satisfaction  age  age_group  \
# 0      BJP       BJP  Fully Dissatisfied  Fully Dissatisfied   26         26
# 1     RLSP     JD(U)  Somewhat Satisfied  Fully Dissatisfied   34         34
#
#   gender  assembly_no category    weight
# 0   Male          211      Gen  0.346969
# 1   Male          189       BC  0.603419

# %%
data1= data[(data.age >=18) & (data.age <25)]

# %%
data1.head(2)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 4            5       5-24-2017       Rural   Graduate  ₹ 50,000 - ₹ 80,000
# 8            9       5-24-2017       Urban  12th Pass    BPL/Below ₹ 5,000
#
#   Vote_Now     Past_Vote  CM_satisfaction    MLA_satisfaction  age  age_group  \
# 4    JD(U)  Did not vote  Fully Satisfied     Fully Satisfied   22         22
# 8      BJP           BJP  Fully Satisfied  Fully Dissatisfied   23         23
#
#   gender  assembly_no category    weight
# 4   Male          176       BC  0.333505
# 8   Male          181      Gen  0.226477

# %%
data1["age_group"]= "18-25"
# Out:
# C:\Users\KARAN\AppData\Local\Temp\ipykernel_20092\1782163204.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1["age_group"]= "18-25"

# %%
data2= data[(data.age >25) & (data.age <40)]

# %%
data2.head(2)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
#
#   Vote_Now Past_Vote     CM_satisfaction    MLA_satisfaction  age  age_group  \
# 0      BJP       BJP  Fully Dissatisfied  Fully Dissatisfied   26         26
# 1     RLSP     JD(U)  Somewhat Satisfied  Fully Dissatisfied   34         34
#
#   gender  assembly_no category    weight
# 0   Male          211      Gen  0.346969
# 1   Male          189       BC  0.603419

# %%
data2["age_group"].unique()
# Out:
# array([26, 34, 36, 38, 29, 30, 39, 37, 32, 27, 28, 35, 31, 33])

# %%
data2["age_group"] = "25-40"
# Out:
# C:\Users\KARAN\AppData\Local\Temp\ipykernel_20092\2001479003.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2["age_group"] = "25-40"

# %%
data2.head(2)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
#
#   Vote_Now Past_Vote     CM_satisfaction    MLA_satisfaction  age age_group  \
# 0      BJP       BJP  Fully Dissatisfied  Fully Dissatisfied   26     25-40
# 1     RLSP     JD(U)  Somewhat Satisfied  Fully Dissatisfied   34     25-40
#
#   gender  assembly_no category    weight
# 0   Male          211      Gen  0.346969
# 1   Male          189       BC  0.603419

# %%
data3= data[(data.age >40) & (data.age <55)]

# %%
data3.age_group.unique()
# Out:
# array([42, 51, 44, 53, 48, 45, 49, 46, 43, 41, 50, 54, 47, 52])

# %%
data3.age_group = "40-55"
# Out:
# C:\Users\KARAN\AppData\Local\Temp\ipykernel_20092\180403481.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3.age_group = "40-55"

# %%
data3.head(2)
# Out:
#     response_id collection_date urban_rural          education  \
# 11           12       5-24-2017       Urban           Graduate
# 12           13       5-24-2017       Urban  Post - Graduation
#
#                  income   Vote_Now Past_Vote        CM_satisfaction  \
# 11  ₹ 10,000 - ₹ 20,000        LJP     JD(U)     Somewhat Satisfied
# 12   ₹ 5,000 - ₹ 10,000  Undecided     JD(U)  Somewhat Dissatisfied
#
#          MLA_satisfaction  age age_group gender  assembly_no category  \
# 11     Fully Dissatisfied   42     40-55   Male          183       BC
# 12  Somewhat Dissatisfied   51     40-55   Male          183       SC
#
#        weight
# 11   2.824391
# 12  20.558759

# %%
data4= data[(data.age >= 55)]

# %%
data4.head(2)
# Out:
#     response_id collection_date urban_rural education               income  \
# 69           70       5-24-2017       Rural  Graduate  ₹ 30,000 - ₹ 50,000
# 74           75       5-24-2017       Urban  Graduate  ₹ 30,000 - ₹ 50,000
#
#    Vote_Now Past_Vote        CM_satisfaction    MLA_satisfaction  age  \
# 69      RJD       INC     Fully Dissatisfied     Fully Satisfied   74
# 74      BJP       BJP  Somewhat Dissatisfied  Somewhat Satisfied   70
#
#     age_group gender  assembly_no category    weight
# 69         74   Male          192       ST  1.805903
# 74         70   Male          183       BC  0.343147

# %%
data4.age_group = "55+"
# Out:
# C:\Users\KARAN\AppData\Local\Temp\ipykernel_20092\2401456332.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data4.age_group = "55+"

# %%
data4.head(2)
# Out:
#     response_id collection_date urban_rural education               income  \
# 69           70       5-24-2017       Rural  Graduate  ₹ 30,000 - ₹ 50,000
# 74           75       5-24-2017       Urban  Graduate  ₹ 30,000 - ₹ 50,000
#
#    Vote_Now Past_Vote        CM_satisfaction    MLA_satisfaction  age  \
# 69      RJD       INC     Fully Dissatisfied     Fully Satisfied   74
# 74      BJP       BJP  Somewhat Dissatisfied  Somewhat Satisfied   70
#
#    age_group gender  assembly_no category    weight
# 69       55+   Male          192       ST  1.805903
# 74       55+   Male          183       BC  0.343147

# %%
data= pd.concat([data1, data2, data3, data4])

# %%
data
# Out:
#       response_id collection_date urban_rural               education  \
# 4               5       5-24-2017       Rural                Graduate
# 8               9       5-24-2017       Urban               12th Pass
# 14             15       5-24-2017       Rural                Graduate
# 16             17       5-24-2017       Rural       Post - Graduation
# 18             19       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6649         6650       5-30-2017       Urban                Graduate
# 6702         6703       5-31-2017       Urban  Professional Education
# 6720         6721       5-31-2017       Rural                Graduate
# 6787         6788        6-1-2017       Rural               10th Pass
# 6851         6852        6-1-2017       Urban                Graduate
#
#                    income    Vote_Now     Past_Vote        CM_satisfaction  \
# ...

# %%
plt.pie(data.age_group.value_counts(), labels=data.age_group.value_counts().index, autopct= "%0.2f", explode= [0.1,0,0,0])
plt.show()

# %% [markdown]
# **Question 5 - How many samples were collected for each age-group? Which age-group had the most samples, show with the help of bar graph?**

# %%
data.head(2)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 4            5       5-24-2017       Rural   Graduate  ₹ 50,000 - ₹ 80,000
# 8            9       5-24-2017       Urban  12th Pass    BPL/Below ₹ 5,000
#
#   Vote_Now     Past_Vote  CM_satisfaction    MLA_satisfaction  age age_group  \
# 4    JD(U)  Did not vote  Fully Satisfied     Fully Satisfied   22     18-25
# 8      BJP           BJP  Fully Satisfied  Fully Dissatisfied   23     18-25
#
#   gender  assembly_no category    weight
# 4   Male          176       BC  0.333505
# 8   Male          181      Gen  0.226477

# %%
data.age_group.value_counts()          # '25-40' has the maximum samples
# Out:
# age_group
# 25-40    3246
# 18-25    2094
# 40-55     624
# 55+       128
# Name: count, dtype: int64

# %%
data.age_group.value_counts().plot(kind= "bar")
# Out:
# <Axes: xlabel='age_group'>

# %% [markdown]
# **Question 6 - What proportion of the respondents had opted for the RJD party in both the Vote_Now and the Past_Vote questions?**

# %%
survey.head(2)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
#
#   Vote_Now Past_Vote     CM_satisfaction    MLA_satisfaction  age gender  \
# 0      BJP       BJP  Fully Dissatisfied  Fully Dissatisfied   26   Male
# 1     RLSP     JD(U)  Somewhat Satisfied  Fully Dissatisfied   34   Male
#
#    assembly_no category    weight
# 0          211      Gen  0.346969
# 1          189       BC  0.603419

# %%
survey[(survey["Vote_Now"] == "RJD") & (survey["Past_Vote"] == "RJD")]
# Out:
#       response_id collection_date urban_rural          education  \
# 3               4       5-24-2017       Urban           Graduate
# 9              10       5-24-2017       Urban          12th Pass
# 16             17       5-24-2017       Rural  Post - Graduation
# 19             20       5-24-2017       Rural           Graduate
# 21             22       5-24-2017       Rural           Graduate
# ...           ...             ...         ...                ...
# 6846         6847        6-1-2017       Rural  Post - Graduation
# 6848         6849        6-1-2017       Rural  Post - Graduation
# 6858         6859        6-1-2017       Rural           Graduate
# 6860         6861        6-1-2017       Rural           Graduate
# 6863         6864        6-1-2017       Rural           Graduate
#
#                    income Vote_Now Past_Vote     CM_satisfaction  \
# 3     ₹ 10,000 - ₹ 20,000      RJD       RJD  Fully Dissatisfied
# ...

# %%
811/ 6867 *100            # RJD votes/ Over all sample size
# Out:
# 11.810106305519149

# %% [markdown]
# **Question 7 - For each day of sample collection, determine the proportion of respondents who were fully satisfied with the performance of the CM.
# So if there were a total of 1000 samples on day 1 and 300 out of those said they were fully satisfied,
# then our answer for that day would be 0.3.**

# %%
survey.head(2)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
#
#   Vote_Now Past_Vote     CM_satisfaction    MLA_satisfaction  age gender  \
# 0      BJP       BJP  Fully Dissatisfied  Fully Dissatisfied   26   Male
# 1     RLSP     JD(U)  Somewhat Satisfied  Fully Dissatisfied   34   Male
#
#    assembly_no category    weight
# 0          211      Gen  0.346969
# 1          189       BC  0.603419

# %%
cm= survey[survey["CM_satisfaction"] == "Fully Dissatisfied"]

# %%
cm.head(2)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 2            3       5-24-2017       Rural   Graduate   ₹ 5,000 - ₹ 10,000
#
#   Vote_Now Past_Vote     CM_satisfaction    MLA_satisfaction  age gender  \
# 0      BJP       BJP  Fully Dissatisfied  Fully Dissatisfied   26   Male
# 2   JAP(L)       BJP  Fully Dissatisfied  Somewhat Satisfied   25   Male
#
#    assembly_no category    weight
# 0          211      Gen  0.346969
# 2          191      Gen  0.673762

# %%
a= cm.collection_date.value_counts()

# %%
a
# Out:
# collection_date
# 5-24-2017    642
# 5-25-2017    433
# 5-28-2017    349
# 5-27-2017    294
# 5-29-2017    283
# 5-26-2017    258
# 6-1-2017     252
# 5-31-2017    251
# 5-30-2017    250
# Name: count, dtype: int64

# %%
b= survey.collection_date.value_counts()

# %%
b
# Out:
# collection_date
# 5-24-2017    1479
# 5-25-2017     998
# 5-28-2017     761
# 5-27-2017     665
# 5-29-2017     620
# 6-1-2017      607
# 5-26-2017     598
# 5-30-2017     582
# 5-31-2017     557
# Name: count, dtype: int64

# %%
a/b*100
# Out:
# collection_date
# 5-24-2017    43.407708
# 5-25-2017    43.386774
# 5-26-2017    43.143813
# 5-27-2017    44.210526
# 5-28-2017    45.860710
# 5-29-2017    45.645161
# 5-30-2017    42.955326
# 5-31-2017    45.062837
# 6-1-2017     41.515651
# Name: count, dtype: float64

# %% [markdown]
# **Question 8 - In a similar fashion create a day-wise proportion of respondents that opted fully dissatisfied with their MLA.
# Create a line plot of the result with date on x-axis and proportions on the y-axis.**

# %%
survey.head(2)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
#
#   Vote_Now Past_Vote     CM_satisfaction    MLA_satisfaction  age gender  \
# 0      BJP       BJP  Fully Dissatisfied  Fully Dissatisfied   26   Male
# 1     RLSP     JD(U)  Somewhat Satisfied  Fully Dissatisfied   34   Male
#
#    assembly_no category    weight
# 0          211      Gen  0.346969
# 1          189       BC  0.603419

# %%
mla= survey[survey.MLA_satisfaction == "Fully Dissatisfied"]

# %%
mla
# Out:
#       response_id collection_date urban_rural  education               income  \
# 0               1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1               2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
# 5               6       5-24-2017       Urban   Graduate  ₹ 20,000 - ₹ 30,000
# 6               7       5-24-2017       Urban   Graduate    BPL/Below ₹ 5,000
# 8               9       5-24-2017       Urban  12th Pass    BPL/Below ₹ 5,000
# ...           ...             ...         ...        ...                  ...
# 6855         6856        6-1-2017       Rural  12th Pass   ₹ 5,000 - ₹ 10,000
# 6857         6858        6-1-2017       Rural  12th Pass    BPL/Below ₹ 5,000
# 6862         6863        6-1-2017       Rural  10th Pass    BPL/Below ₹ 5,000
# 6863         6864        6-1-2017       Rural   Graduate    BPL/Below ₹ 5,000
# 6864         6865        6-1-2017       Urban   Graduate   ₹ 5,000 - ₹ 10,000
#
# ...

# %%
c= mla.collection_date.value_counts()

# %%
c
# Out:
# collection_date
# 5-24-2017    887
# 5-25-2017    630
# 5-28-2017    462
# 5-27-2017    403
# 6-1-2017     385
# 5-30-2017    361
# 5-26-2017    353
# 5-29-2017    350
# 5-31-2017    321
# Name: count, dtype: int64

# %%
d= survey.collection_date.value_counts()

# %%
print(d)
# Out:
# collection_date
# 5-24-2017    1479
# 5-25-2017     998
# 5-28-2017     761
# 5-27-2017     665
# 5-29-2017     620
# 6-1-2017      607
# 5-26-2017     598
# 5-30-2017     582
# 5-31-2017     557
# Name: count, dtype: int64

# %%
result1 =c/d *100

# %%
result1
# Out:
# collection_date
# 5-24-2017    59.972955
# 5-25-2017    63.126253
# 5-26-2017    59.030100
# 5-27-2017    60.601504
# 5-28-2017    60.709593
# 5-29-2017    56.451613
# 5-30-2017    62.027491
# 5-31-2017    57.630162
# 6-1-2017     63.426689
# Name: count, dtype: float64

# %%
g= pd.DataFrame(result1)

# %%
g
# Out:
#                      count
# collection_date
# 5-24-2017        59.972955
# 5-25-2017        63.126253
# 5-26-2017        59.030100
# 5-27-2017        60.601504
# 5-28-2017        60.709593
# 5-29-2017        56.451613
# 5-30-2017        62.027491
# 5-31-2017        57.630162
# 6-1-2017         63.426689

# %%
g.plot(kind = "line", figsize= (10,5))
# Out:
# <Axes: xlabel='collection_date'>

# %% [markdown]
# **Question 9 - Create a pivot-table (or crosstab) with index as Past_Vote, Column as Vote_Now and cell values as the count of samples.**

# %%
survey.head(2)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
#
#   Vote_Now Past_Vote     CM_satisfaction    MLA_satisfaction  age gender  \
# 0      BJP       BJP  Fully Dissatisfied  Fully Dissatisfied   26   Male
# 1     RLSP     JD(U)  Somewhat Satisfied  Fully Dissatisfied   34   Male
#
#    assembly_no category    weight
# 0          211      Gen  0.346969
# 1          189       BC  0.603419

# %%
pivot1= survey.pivot_table(index= "Past_Vote", columns= "Vote_Now", aggfunc= "count")

# %%
pivot1
# Out:
#              CM_satisfaction                                              \
# Vote_Now                 AAP AIMIM     BJP  BSP  HAM   INC JAP(L)  JD(U)
# Past_Vote
# BJP                      7.0   1.0  1630.0  3.0  5.0  42.0  101.0  110.0
# BSP                      NaN   1.0     2.0  5.0  NaN   1.0    NaN    NaN
# Did not vote             8.0   5.0   231.0  2.0  1.0  22.0   41.0   69.0
# HAM                      2.0   NaN    25.0  NaN  1.0   NaN    3.0    2.0
# INC                      NaN   6.0     6.0  NaN  NaN  57.0   10.0    9.0
# JAP(L)                   NaN   NaN     4.0  NaN  NaN   NaN   35.0    NaN
# JD(U)                    6.0  10.0   254.0  2.0  2.0  45.0   72.0  279.0
# LJP                      NaN   NaN    76.0  1.0  NaN   4.0    3.0    6.0
# Left Front               NaN   1.0     2.0  NaN  NaN   1.0    NaN    NaN
# NOTA                     NaN   1.0    29.0  1.0  NaN   9.0    7.0    7.0
# Others                   1.0   5.0    45.0  1.0  1.0   4.0    7.0    4.0
# ...

# %% [markdown]
# **Question 10 - Repeat the above question with the cell values as the sum of “weight”.**

# %%
survey.head(2)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
#
#   Vote_Now Past_Vote     CM_satisfaction    MLA_satisfaction  age gender  \
# 0      BJP       BJP  Fully Dissatisfied  Fully Dissatisfied   26   Male
# 1     RLSP     JD(U)  Somewhat Satisfied  Fully Dissatisfied   34   Male
#
#    assembly_no category    weight
# 0          211      Gen  0.346969
# 1          189       BC  0.603419

# %%
pivot2= survey.pivot_table(index= "Past_Vote", columns= "Vote_Now", values= "weight" ,aggfunc= "sum")

# %%
pivot2
# Out:
# Vote_Now            AAP      AIMIM          BJP        BSP        HAM  \
# Past_Vote
# BJP            4.807335   0.349996  1049.344112   0.452551  10.171283
# BSP                 NaN   1.654731     5.174487  32.010277        NaN
# Did not vote   8.865896   5.379527   114.203906   3.329611   2.497170
# HAM            0.312607        NaN    25.348884        NaN   1.648856
# INC                 NaN  11.105958     1.642875        NaN        NaN
# JAP(L)              NaN        NaN     6.512846        NaN        NaN
# JD(U)         12.457216  29.198610   156.243100  11.005903   2.639574
# LJP                 NaN        NaN    85.010450   2.481377        NaN
# Left Front          NaN   2.298223     0.209586        NaN        NaN
# NOTA                NaN   1.061204    12.685435   0.051485        NaN
# Others        13.661335  21.212705    34.866218   0.684568   1.505864
# RJD            5.515847  24.149369    32.285093        NaN   0.960400
# ...

# %% [markdown]
# **Question 11 - Create a dataframe by performing a group by over age_group and calculate the count of total samples under each age_group.**

# %%
survey.head(2)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
#
#   Vote_Now Past_Vote     CM_satisfaction    MLA_satisfaction  age gender  \
# 0      BJP       BJP  Fully Dissatisfied  Fully Dissatisfied   26   Male
# 1     RLSP     JD(U)  Somewhat Satisfied  Fully Dissatisfied   34   Male
#
#    assembly_no category    weight
# 0          211      Gen  0.346969
# 1          189       BC  0.603419

# %%
x= data.groupby("age_group").count()

# %%
x
# Out:
#            response_id  collection_date  urban_rural  education  income  \
# age_group
# 18-25             2094             2094         2094       2094    2094
# 25-40             3246             3246         3246       3246    3246
# 40-55              624              624          624        624     624
# 55+                128              128          128        128     128
#
#            Vote_Now  Past_Vote  CM_satisfaction  MLA_satisfaction   age  \
# age_group
# 18-25          2094       2094             2094              2094  2094
# 25-40          3246       3246             3246              3246  3246
# 40-55           624        624              624               624   624
# 55+             128        128              128               128   128
#
#            gender  assembly_no  category  weight
# age_group
# 18-25        2094         2094      2094    2094
# 25-40        3246         3246      3246    3246
# 40-55         624          624       624     624
# ...

# %% [markdown]
# **Question 12 - Create a dataframe by performing a group by over age_group and finding the count of total samples for each age_group that opted for the JD(U) party in Vote_Now.**

# %%
jdu= data[data["Vote_Now"] == "JD(U)"]

# %%
jdu
# Out:
#       response_id collection_date urban_rural          education  \
# 4               5       5-24-2017       Rural           Graduate
# 67             68       5-24-2017       Urban          12th Pass
# 75             76       5-24-2017       Rural           Graduate
# 90             91       5-24-2017       Rural           Graduate
# 102           103       5-24-2017       Rural           Graduate
# ...           ...             ...         ...                ...
# 5248         5249       5-24-2017       Urban  Post - Graduation
# 5956         5957        6-1-2017       Urban          12th Pass
# 6341         6342       5-26-2017       Rural  Post - Graduation
# 6499         6500       5-28-2017       Rural           Graduate
# 6787         6788        6-1-2017       Rural          10th Pass
#
#                      income Vote_Now     Past_Vote     CM_satisfaction  \
# 4       ₹ 50,000 - ₹ 80,000    JD(U)  Did not vote     Fully Satisfied
# ...

# %%
y= jdu.groupby("age_group").count()

# %%
y
# Out:
#            response_id  collection_date  urban_rural  education  income  \
# age_group
# 18-25              181              181          181        181     181
# 25-40              229              229          229        229     229
# 40-55               52               52           52         52      52
# 55+                 13               13           13         13      13
#
#            Vote_Now  Past_Vote  CM_satisfaction  MLA_satisfaction  age  \
# age_group
# 18-25           181        181              181               181  181
# 25-40           229        229              229               229  229
# 40-55            52         52               52                52   52
# 55+              13         13               13                13   13
#
#            gender  assembly_no  category  weight
# age_group
# 18-25         181          181       181     181
# 25-40         229          229       229     229
# 40-55          52           52        52      52
# ...

# %% [markdown]
# **Question 13 - Join/Merge the two dataframes from questions 12 and 11 with the common column as age_group.**

# %%
result= pd.merge(y,x,on="age_group", how= "left")

# %%
result
# Out:
#            response_id_x  collection_date_x  urban_rural_x  education_x  \
# age_group
# 18-25                181                181            181          181
# 25-40                229                229            229          229
# 40-55                 52                 52             52           52
# 55+                   13                 13             13           13
#
#            income_x  Vote_Now_x  Past_Vote_x  CM_satisfaction_x  \
# age_group
# 18-25           181         181          181                181
# 25-40           229         229          229                229
# 40-55            52          52           52                 52
# 55+              13          13           13                 13
#
#            MLA_satisfaction_x  age_x  ...  income_y  Vote_Now_y  Past_Vote_y  \
# age_group                             ...
# 18-25                     181    181  ...      2094        2094         2094
# ...
